# %% [markdown]
# **Logistic Regresssion, Decision Boundary:**

# %%
import numpy as np
# %matplotlib widget
import matplotlib.pyplot as plt
from lab_utils_common import plot_data, sigmoid, draw_vthresh
plt.style.use('./deeplearning.mplstyle')

# %%
X = np.array([[0.5, 1.5], [1,1], [1.5, 0.5], [3, 0.5], [2, 2], [1, 2.5]])
y = np.array([0, 0, 0, 1, 1, 1]).reshape(-1,1) 
print(X.shape)
print(y.shape)
# Out:
# (6, 2)
# (6, 1)

# %% [markdown]
# **Plot data:**

# %%
pos = y == 1
neg = y == 0
pos = pos.reshape(-1,)  #work with 1D or 1D y vectors
neg = neg.reshape(-1,)
print(pos)
# Out:
# [False False False  True  True  True]

# %%
print(y[pos])
# Out:
# [[1]
#  [1]
#  [1]]

# %%
print(X[pos])
# Out:
# [[3.  0.5]
#  [2.  2. ]
#  [1.  2.5]]

# %%
print(X[pos, 0])
# Out:
# [3. 2. 1.]

# %%
fig, ax = plt.subplots(1, 1, figsize=(4, 4))
pos = y == 1
neg = y == 0
pos = pos.reshape(-1,)  #work with 1D or 1D y vectors
neg = neg.reshape(-1,)

# Plot examples
ax.scatter(X[pos, 0], X[pos, 1], marker='x', c = 'red')
ax.scatter(X[neg, 0], X[neg, 1], marker='o', facecolors='none', edgecolors='aqua', lw=3)
# Fill the region below the line
ax.axis([0, 4, 0, 3.5])
ax.set_ylabel('$x_1$')
ax.set_xlabel('$x_0$')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 11
#       9 ax.scatter(X[neg, 0], X[neg, 1], marker='o', facecolors='none', edgecolors='aqua', lw=3)
#      10 # Fill the region below the line
# ---> 11 ax.fill_between(x0,x1, alpha=0.2)
#      12 ax.axis([0, 4, 0, 3.5])
#      13 ax.set_ylabel('$x_1$')
#
# NameError: name 'x0' is not defined
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
