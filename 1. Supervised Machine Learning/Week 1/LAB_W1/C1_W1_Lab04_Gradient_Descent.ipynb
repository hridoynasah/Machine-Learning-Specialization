# %%
import math, copy
import numpy as np
import matplotlib.pyplot as plt

# %%
x_train = np.array([1.0, 2.0])
y_train = np.array([300.0, 500.0])

# %%
print(f"Shape of x_train: {x_train.shape}")
print(f"Dim of x_train: {x_train.ndim}")
print(f"Shape of y_train: {y_train.shape}")
print(f"Dim of y_train: {y_train.ndim}")
# Out:
# Shape of x_train: (2,)
# Dim of x_train: 1
# Shape of y_train: (2,)
# Dim of y_train: 1

# %%
# Compute cost 
def compute_cost(x, y, w, b):
    cost = 0
    m = x.shape[0]
    for i in range(m):
        f_wb = w * x[i] + b
        mse = (f_wb - y[i]) ** 2
        cost = cost + mse
    
    return (cost / 2*m)

# %%
# Compute Gradient 
def compute_gradient(x, y, w, b):
    dj_dw = 0
    dj_db = 0
    m = x.shape[0]
    for i in range(m):
        f_wb = w * x[i] + b
        dj_dw += (f_wb - y[i]) * x[i]
        dj_db += (f_wb - y[i])
    
    return (dj_dw/m), (dj_db/m)

# %%
def gradient_descent(x, y, alpha, epoch):
    J_history = []
    wb_history = []
    w = 0
    b = 0
    for i in range(epoch):
        dj_dw, dj_db = compute_gradient(x, y, w, b)

        w = w - alpha * dj_dw
        b = b - alpha * dj_dw
        if i < 100000:
            J_history.append(compute_cost(x, y, w, b))
            wb_history.append([w,b])
        if i % 1000 == 0:
            print(f"Iteration {i:4}: Cost {J_history[-1]:0.2e} ",
                  f"dj_dw: {dj_dw: 0.3e}, dj_db: {dj_db: 0.3e}  ",
                  f"w: {w: 0.3e}, b:{b: 0.5e}")
    return w, b, J_history, wb_history

# %%
alpha = 1.0e-2
epoch = 10000
w_final, b_final, J_hist, wb_hist = gradient_descent(x_train, y_train,
                                                    alpha, epoch)
print(f"(w,b) found by gradient descent: ({w_final:8.4f},{b_final:8.4f})")
# Out:
# Iteration    0: Cost 3.13e+05  dj_dw: -6.500e+02, dj_db: -4.000e+02   w:  6.500e+00, b: 6.50000e+00
# Iteration 1000: Cost 7.81e+02  dj_dw: -1.364e-12, dj_db:  6.250e+00   w:  1.625e+02, b: 1.62500e+02
# Iteration 2000: Cost 7.81e+02  dj_dw: -1.364e-12, dj_db:  6.250e+00   w:  1.625e+02, b: 1.62500e+02
# Iteration 3000: Cost 7.81e+02  dj_dw: -1.364e-12, dj_db:  6.250e+00   w:  1.625e+02, b: 1.62500e+02
# Iteration 4000: Cost 7.81e+02  dj_dw: -1.364e-12, dj_db:  6.250e+00   w:  1.625e+02, b: 1.62500e+02
# Iteration 5000: Cost 7.81e+02  dj_dw: -1.364e-12, dj_db:  6.250e+00   w:  1.625e+02, b: 1.62500e+02
# Iteration 6000: Cost 7.81e+02  dj_dw: -1.364e-12, dj_db:  6.250e+00   w:  1.625e+02, b: 1.62500e+02
# Iteration 7000: Cost 7.81e+02  dj_dw: -1.364e-12, dj_db:  6.250e+00   w:  1.625e+02, b: 1.62500e+02
# Iteration 8000: Cost 7.81e+02  dj_dw: -1.364e-12, dj_db:  6.250e+00   w:  1.625e+02, b: 1.62500e+02
# ...

# %%
# plot cost versus iteration  
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,4))
ax1.plot(J_hist[:100])
ax2.plot(range(1000, len(J_hist)), J_hist[1000:])
ax1.set_title("Cost vs. iteration(start)");  ax2.set_title("Cost vs. iteration (end)")
ax1.set_ylabel('Cost')            ;  ax2.set_ylabel('Cost') 
ax1.set_xlabel('iteration step')  ;  ax2.set_xlabel('iteration step') 
ax1.grid(True)
ax2.grid(True)
plt.show()
